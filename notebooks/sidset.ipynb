# %%
import os

from dotenv import load_dotenv

load_dotenv()

DATA_PATH = os.environ["DATA_PATH"]
DATA_PATH
# Out:
# '/home/workspace/data'

# %%
from trustfake.data import SIDSetDataModule, visualize_sample

datamodule = SIDSetDataModule(data_dir=DATA_PATH, profile="smoke")
datamodule.setup()

# %%
visualize_sample(datamodule, index=0, split="train")
